# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')


plt.style.use("fivethirtyeight")
# %matplotlib inline

pd.set_option('display.max_columns', 30)

# %%
df = pd.read_csv('kidney_disease.csv')

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr    bu   sc    sod  pot  hemo pcv    wc   rc  htn   dm cad appet   pe  \
# 0  121.0  36.0  1.2    NaN  NaN  15.4  44  7800  5.2  yes  yes  no  good   no
# 1    NaN  18.0  0.8    NaN  NaN  11.3  38  6000  NaN   no   no  no  good   no
# 2  423.0  53.0  1.8    NaN  NaN   9.6  31  7500  NaN   no  yes  no  poor   no
# 3  117.0  56.0  3.8  111.0  2.5  11.2  32  6700  3.9  yes   no  no  poor  yes
# 4  106.0  26.0  1.4    NaN  NaN  11.6  35  7300  4.6   no   no  no  good   no
#
#    ane classification
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
df.drop(columns=['id'], axis=1, inplace = True)

# %%
df.shape
# Out:
# (400, 25)

# %%
df.head(1)
# Out:
#     age    bp    sg   al   su  rbc      pc         pcc          ba    bgr  \
# 0  48.0  80.0  1.02  1.0  0.0  NaN  normal  notpresent  notpresent  121.0
#
#      bu   sc  sod  pot  hemo pcv    wc   rc  htn   dm cad appet  pe ane  \
# 0  36.0  1.2  NaN  NaN  15.4  44  7800  5.2  yes  yes  no  good  no  no
#
#   classification
# 0            ckd

# %%
df.rename(
    columns = {
        'bp' : 'blood_pressure',
        'sg' : 'specific_gravity',
        'al' : 'albumin',
        'su' : 'sugar',
        'rbc' : 'red_blood_cells',
        'pc' : 'pus_cell',
        'pcc' : 'pus_cell_clumps',
        'ba' : 'bacteria',
        'bgr' : 'blood_glucose_random',
        'bu' : 'blood_urea',
        'sc' : 'serum_creatinine',
        'sod' : 'sodium',
        'pot' : 'potassium',
        'hemo' : 'haemoglobin',
        'pcv' : 'packed_cell_volume',
        'wc' : 'white_blood_cell_count',
        'rc' : 'red_blood_cell_count',
        'htn' : 'hypertension',
        'dm' : 'diabetes_mellitus',
        'cad' : 'coronary_artery_disease',
        'appet' : 'appetite',
        'pe' : 'peda_edema',
        'ane': 'aanemia',
        'classification' : 'class' 
    }, 
    inplace = True
)

# %%
df
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood_glucose_random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume          object
# white_blood_cell_count      object
# red_blood_cell_count        object
# hypertension                object
# diabetes_mellitus           object
# coronary_artery_disease     object
# appetite                    object
# peda_edema                  object
# aanemia                     object
# class                       object
# dtype: object

# %%
df['packed_cell_volume']
# Out:
# 0      44
# 1      38
# 2      31
# 3      32
# 4      35
#        ..
# 395    47
# 396    54
# 397    49
# 398    51
# 399    53
# Name: packed_cell_volume, Length: 400, dtype: object

# %%
df['packed_cell_volume'].dtype
# Out:
# dtype('O')

# %%
df['packed_cell_volume'].value_counts()
# Out:
# 41      21
# 52      21
# 44      19
# 48      19
# 40      16
# 43      14
# 42      13
# 45      13
# 32      12
# 36      12
# 33      12
# 50      12
# 28      12
# 34      11
# 37      11
# 30       9
# 29       9
# 35       9
# 46       9
# 31       8
# 24       7
# 39       7
# 26       6
# 38       5
# 53       4
# 51       4
# 49       4
# 47       4
# 54       4
# 25       3
# 27       3
# 22       3
# 19       2
# 23       2
# 15       1
# 21       1
# 17       1
# 20       1
# \t43     1
# 18       1
# 9        1
# 14       1
# \t?      1
# 16       1
# Name: packed_cell_volume, dtype: int64

# %%
df['packed_cell_volume'] = pd.to_numeric(df['packed_cell_volume'], errors='raise')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2363, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "	?"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['packed_cell_volume'] = pd.to_numeric(df['packed_cell_volume'], errors='raise')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/tools/numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# ...

# %%
df['packed_cell_volume'] = pd.to_numeric(df['packed_cell_volume'], errors='coerce')

# %%
df['packed_cell_volume'].value_counts()
# Out:
# 41.0    21
# 52.0    21
# 44.0    19
# 48.0    19
# 40.0    16
# 43.0    15
# 42.0    13
# 45.0    13
# 32.0    12
# 50.0    12
# 36.0    12
# 33.0    12
# 28.0    12
# 34.0    11
# 37.0    11
# 30.0     9
# 29.0     9
# 35.0     9
# 46.0     9
# 31.0     8
# 24.0     7
# 39.0     7
# 26.0     6
# 38.0     5
# 53.0     4
# 51.0     4
# 49.0     4
# 47.0     4
# 54.0     4
# 25.0     3
# 27.0     3
# 22.0     3
# 19.0     2
# 23.0     2
# 15.0     1
# 21.0     1
# 20.0     1
# 17.0     1
# 9.0      1
# 18.0     1
# 14.0     1
# 16.0     1
# Name: packed_cell_volume, dtype: int64

# %%
## Now, lets fouc of white_blood_cell_count feature

df['white_blood_cell_count'].dtype
# Out:
# dtype('O')

# %%
df['white_blood_cell_count']
# Out:
# 0      7800
# 1      6000
# 2      7500
# 3      6700
# 4      7300
#        ...
# 395    6700
# 396    7800
# 397    6600
# 398    7200
# 399    6800
# Name: white_blood_cell_count, Length: 400, dtype: object

# %%
df['white_blood_cell_count'].value_counts()
# Out:
# 9800     11
# 6700     10
# 9200      9
# 9600      9
# 7200      9
#          ..
# 19100     1
# \t?       1
# 12300     1
# 14900     1
# 12700     1
# Name: white_blood_cell_count, Length: 92, dtype: int64

# %%
df['white_blood_cell_count'].isna().sum()
# Out:
# 105

# %%
df['white_blood_cell_count'] = pd.to_numeric(df['white_blood_cell_count'], errors= 'coerce')

# %%
df['white_blood_cell_count'].isna().sum()
# Out:
# 106

# %%
df['white_blood_cell_count']
# Out:
# 0      7800.0
# 1      6000.0
# 2      7500.0
# 3      6700.0
# 4      7300.0
#         ...
# 395    6700.0
# 396    7800.0
# 397    6600.0
# 398    7200.0
# 399    6800.0
# Name: white_blood_cell_count, Length: 400, dtype: float64

# %%
# lets focus on red blood cells

df['red_blood_cell_count'].dtype
# Out:
# dtype('O')

# %%
df['red_blood_cell_count']
# Out:
# 0      5.2
# 1      NaN
# 2      NaN
# 3      3.9
# 4      4.6
#       ...
# 395    4.9
# 396    6.2
# 397    5.4
# 398    5.9
# 399    6.1
# Name: red_blood_cell_count, Length: 400, dtype: object

# %%
df['red_blood_cell_count'].value_counts()
# Out:
# 5.2    18
# 4.5    16
# 4.9    14
# 4.7    11
# 4.8    10
# 3.9    10
# 4.6     9
# 3.4     9
# 5.9     8
# 5.5     8
# 6.1     8
# 5.0     8
# 3.7     8
# 5.3     7
# 5.8     7
# 5.4     7
# 3.8     7
# 5.6     6
# 4.3     6
# 4.2     6
# 3.2     5
# 4.4     5
# 5.7     5
# 6.4     5
# 5.1     5
# 6.2     5
# 6.5     5
# 4.1     5
# 3.6     4
# 6.3     4
# 6.0     4
# 4.0     3
# 3.3     3
# 4       3
# 3.5     3
# 2.9     2
# 3.1     2
# 2.6     2
# 2.1     2
# 2.5     2
# 2.8     2
# 3.0     2
# 2.7     2
# 5       2
# 2.3     1
# \t?     1
# 2.4     1
# 3       1
# 8.0     1
# Name: red_blood_cell_count, dtype: int64

# %%
df['red_blood_cell_count'] = pd.to_numeric(df['red_blood_cell_count'], errors= 'coerce')

# %%
df['red_blood_cell_count'].value_counts()
# Out:
# 5.2    18
# 4.5    16
# 4.9    14
# 4.7    11
# 5.0    10
# 3.9    10
# 4.8    10
# 4.6     9
# 3.4     9
# 5.9     8
# 3.7     8
# 6.1     8
# 5.5     8
# 5.4     7
# 5.3     7
# 5.8     7
# 3.8     7
# 4.2     6
# 4.3     6
# 4.0     6
# 5.6     6
# 5.1     5
# 6.2     5
# 6.4     5
# 5.7     5
# 6.5     5
# 4.1     5
# 4.4     5
# 3.2     5
# 6.0     4
# 3.6     4
# 6.3     4
# 3.3     3
# 3.0     3
# 3.5     3
# 2.6     2
# 2.8     2
# 2.9     2
# 2.5     2
# 2.7     2
# 2.1     2
# 3.1     2
# 2.3     1
# 2.4     1
# 8.0     1
# Name: red_blood_cell_count, dtype: int64

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']
numerical_features = [feature for feature in df.columns if df[feature].dtype != 'O']

print(f"{len(categorical_features)} categorical features: {categorical_features}")
print(f"{len(numerical_features)} numeircal features: {numerical_features}")
# Out:
# 11 categorical features: ['red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria', 'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'peda_edema', 'aanemia', 'class']
# 14 numeircal features: ['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium', 'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count']

# %%
df.head(1)
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0              1.02      1.0    0.0             NaN
#
#   pus_cell pus_cell_clumps    bacteria  blood_glucose_random  blood_urea  \
# 0   normal      notpresent  notpresent                 121.0        36.0
#
#    serum_creatinine  sodium  potassium  haemoglobin  packed_cell_volume  \
# 0               1.2     NaN        NaN         15.4                44.0
#
#    white_blood_cell_count  red_blood_cell_count hypertension  \
# 0                  7800.0                   5.2          yes
#
#   diabetes_mellitus coronary_artery_disease appetite peda_edema aanemia class
# 0               yes                      no     good         no      no   ckd

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood_glucose_random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume         float64
# white_blood_cell_count     float64
# red_blood_cell_count       float64
# hypertension                object
# diabetes_mellitus           object
# coronary_artery_disease     object
# appetite                    object
# peda_edema                  object
# aanemia                     object
# class                       object
# dtype: object

# %%
for col in categorical_features:
    
    print(f"{col} has {df[col].unique()}")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal']
# pus_cell has ['normal' 'abnormal' nan]
# pus_cell_clumps has ['notpresent' 'present' nan]
# bacteria has ['notpresent' 'present' nan]
# hypertension has ['yes' 'no' nan]
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan]
# coronary_artery_disease has ['no' 'yes' '\tno' nan]
# appetite has ['good' 'poor' nan]
# peda_edema has ['no' 'yes' nan]
# aanemia has ['no' 'yes' nan]
# class has ['ckd' 'ckd\t' 'notckd']

# %%
df['diabetes_mellitus'].replace(to_replace = {'\tno' : 'no', '\tyes': 'yes', ' yes': 'yes'}, inplace = True)

# %%
df['diabetes_mellitus'].value_counts()
# Out:
# no     261
# yes    137
# Name: diabetes_mellitus, dtype: int64

# %%
df['coronary_artery_disease'].replace(to_replace = '\tno', value='no', inplace = True)

# %%
df['coronary_artery_disease'].value_counts()
# Out:
# no     364
# yes     34
# Name: coronary_artery_disease, dtype: int64

# %%
df['class'].replace(to_replace={'ckd\t':'ckd', 'notckd':'not ckd'}, inplace = True)

# %%
df['class'].value_counts()
# Out:
# ckd        250
# not ckd    150
# Name: class, dtype: int64

# %%
df['class'].map({'ckd':0, 'not ckd':1})
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    1
# 399    1
# Name: class, Length: 400, dtype: int64

# %%
df['class']
# Out:
# 0          ckd
# 1          ckd
# 2          ckd
# 3          ckd
# 4          ckd
#         ...
# 395    not ckd
# 396    not ckd
# 397    not ckd
# 398    not ckd
# 399    not ckd
# Name: class, Length: 400, dtype: object

# %%
df['age']
# Out:
# 0      48.0
# 1       7.0
# 2      62.0
# 3      48.0
# 4      51.0
#        ...
# 395    55.0
# 396    42.0
# 397    12.0
# 398    17.0
# 399    58.0
# Name: age, Length: 400, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      391 non-null    float64
#  1   blood_pressure           388 non-null    float64
#  2   specific_gravity         353 non-null    float64
#  3   albumin                  354 non-null    float64
#  4   sugar                    351 non-null    float64
#  5   red_blood_cells          248 non-null    object
#  6   pus_cell                 335 non-null    object
#  7   pus_cell_clumps          396 non-null    object
#  8   bacteria                 396 non-null    object
#  9   blood_glucose_random     356 non-null    float64
#  10  blood_urea               381 non-null    float64
#  11  serum_creatinine         383 non-null    float64
#  12  sodium                   313 non-null    float64
#  13  potassium                312 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# age                          9
# blood_pressure              12
# specific_gravity            47
# albumin                     46
# sugar                       49
# red_blood_cells            152
# pus_cell                    65
# pus_cell_clumps              4
# bacteria                     4
# blood_glucose_random        44
# blood_urea                  19
# serum_creatinine            17
# sodium                      87
# potassium                   88
# haemoglobin                 52
# packed_cell_volume          71
# white_blood_cell_count     106
# red_blood_cell_count       131
# hypertension                 2
# diabetes_mellitus            2
# coronary_artery_disease      2
# appetite                     1
# peda_edema                   1
# aanemia                      1
# class                        0
# dtype: int64

# %%
# Univariate Analysis

plt.figure(figsize=(10, 6))
sns.histplot(df['age'], kde=True, color='skyblue')
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
df
# Out:
#       age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0    48.0            80.0             1.020      1.0    0.0             NaN
# 1     7.0            50.0             1.020      4.0    0.0             NaN
# 2    62.0            80.0             1.010      2.0    3.0          normal
# 3    48.0            70.0             1.005      4.0    0.0          normal
# 4    51.0            80.0             1.010      2.0    0.0          normal
# ..    ...             ...               ...      ...    ...             ...
# 395  55.0            80.0             1.020      0.0    0.0          normal
# 396  42.0            70.0             1.025      0.0    0.0          normal
# 397  12.0            80.0             1.020      0.0    0.0          normal
# 398  17.0            60.0             1.025      0.0    0.0          normal
# 399  58.0            80.0             1.025      0.0    0.0          normal
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(data = df, x = df['hypertension'], hue='class' , palette = 'viridis')
# Out:
# <AxesSubplot: xlabel='hypertension', ylabel='count'>

# %%
sns.boxplot(data = df, y = 'blood_urea', x='class' , palette = 'viridis')
# Out:
# <AxesSubplot: xlabel='class', ylabel='blood_urea'>

# %%
sns.violinplot(data = df, x='class', y = 'serum_creatinine', palette = 'viridis')
# Out:
# <AxesSubplot: xlabel='class', ylabel='serum_creatinine'>

# %%
sns.countplot(x='aanemia', data=df, hue='class')
# Out:
# <AxesSubplot: xlabel='aanemia', ylabel='count'>

# %%
df['appetite']
# Out:
# 0      good
# 1      good
# 2      poor
# 3      poor
# 4      good
#        ...
# 395    good
# 396    good
# 397    good
# 398    good
# 399    good
# Name: appetite, Length: 400, dtype: object

# %%
df['appetite'].value_counts(normalize=True).plot.pie(autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'], explode=(0, 0.1), startangle=90)
# Out:
# <AxesSubplot: ylabel='appetite'>

# %%
#79.4% has good appetite

df['appetite'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'], wedgeprops = dict(width=0.3), startangle = 90)
# Out:
# <AxesSubplot: ylabel='appetite'>

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1


for col in numerical_features:
    if plotnumber <= 15:
        ax = plt.subplot(3, 5, plotnumber)
        sns.distplot(df[col])
        plt.xlabel(col)
    plotnumber += 1
    
plt.tight_layout()
plt.show()

# %%
def kde(col):
    grid = sns.FacetGrid(df, hue = "class", height =6, aspect=2)
    grid.map(sns.kdeplot, col)
    grid.add_legend()

# %%
kde('red_blood_cell_count')

# %%
kde('white_blood_cell_count')

# %%
kde('haemoglobin')

# %%
def violin(col):
    fig = px.violin(df, y=col, x='class', box =True, template = 'plotly_dark')
    return fig.show()

# %%
violin('haemoglobin')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 violin('haemoglobin')
#
# Cell In[79], line 2, in violin(col)
#       1 def violin(col):
# ----> 2     fig = px.violin(df, y=col, x='class', box =True, template = 'plotly_dark')
#       3     return fig.show()
#
# NameError: name 'px' is not defined
